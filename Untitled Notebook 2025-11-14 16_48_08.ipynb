-- %%
SELECT SUM(Amount)
FROM crowd2fund.silver.add_withdraw_requests

-- %%
USE CATALOG crowd2fund;

SELECT COUNT(*)
FROM silver.business_transactions
UNION ALL
SELECT COUNT(*)
FROM silver.business_transactions2;
